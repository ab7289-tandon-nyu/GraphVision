# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 1.13.0+cu116
#      |████████████████████████████████| 9.4 MB 35.8 MB/s
#      |████████████████████████████████| 4.6 MB 44.5 MB/s
#      |████████████████████████████████| 3.2 MB 15.6 MB/s
#      |████████████████████████████████| 512 kB 24.3 MB/s
#      |████████████████████████████████| 280 kB 69.6 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
# Install our repo
# !git clone -b models "https://github.com/ab7289-tandon-nyu/GraphVision.git"
# !cp -r /content/GraphVision/src/ .

# !pip install -q git+https://github.com/ab7289-tandon-nyu/GraphVision.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 121 kB 15.5 MB/s
#      |████████████████████████████████| 1.6 MB 56.4 MB/s
#      |████████████████████████████████| 83 kB 2.5 MB/s
#   Building wheel for GraphVision (PEP 517) ... done

# %%
SEED = 1234

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
from src.transforms import get_transforms
from src.datasets import get_datasets, get_dataloaders

transforms = get_transforms("cartesian")
train_dataset, valid_dataset, test_dataset = get_datasets(".data/", 
                        "CIFAR10", pre_transforms = None,
                        transforms = transforms)
BATCH_SIZE = 128

train_loader, valid_loader, test_loader = get_dataloaders(train_dataset,
                                                          valid_dataset,
                                                          test_dataset,
                                                          batch_size=(BATCH_SIZE, 1, 1),
                                                          drop_last = False)
# Out:
# Downloading https://data.pyg.org/datasets/benchmarking-gnns/CIFAR10_v2.zip
# Extracting .data/CIFAR10/raw/CIFAR10_v2.zip
# Processing...
# Done!

# %% [markdown]
# ## Review batch attributes

# %%
sample_batch = next(iter(train_loader))

print()
print(sample_batch)
print("=====================================================================")

# Gather some statistics about the first graph.
print(f"Number of features:  {sample_batch.num_features}")
print(f"Number of node features: {sample_batch.num_node_features}")
print(f'Number of nodes: {sample_batch.num_nodes}')
print(f'Number of edges: {sample_batch.num_edges}')
print(f'Average node degree: {sample_batch.num_edges / sample_batch.num_nodes:.2f}')
print(f'Has isolated nodes: {sample_batch.has_isolated_nodes()}')
print(f'Has self-loops: {sample_batch.has_self_loops()}')
# Out:
# DataBatch(x=[14981, 3], edge_index=[2, 134829], edge_attr=[134829, 2], y=[128], pos=[14981, 2], edge_weight=[134829], batch=[14981], ptr=[129])
# =====================================================================
# Number of features:  3
# Number of node features: 3
# Number of nodes: 14981
# Number of edges: 134829
# Average node degree: 9.00
# Has isolated nodes: False
# Has self-loops: True

# %%
# store edge dimension
edge_dim = sample_batch.edge_attr.size(-1)
edge_dim
# store number of features in graph batch
input_features = test_dataset.num_features
# store number of classes for classification
num_classes = test_dataset.num_classes

print(f"Number of features: {input_features}")
print(f"Number of classes: {num_classes}")
print(f"Edge Attr Dimension: {edge_dim}")
# Out:
# Number of features: 3
# Number of classes: 10
# Edge Attr Dimension: 2

# %%
from pathlib import Path

save_loc = "" # put save location here
model_name = "GATConv_clus-false_BN_RELU_h128_layer4.pt"

file_path = save_loc + model_name
path = Path(file_path)
state_dict = None
if path.exists() and path.is_file():
  print("Found Save!")
  state_dict = torch.load(path)
else:
  print("Creating new Model")
# Out:
# Creating new Model

# %% [markdown]
# ## Create our Model

# %%
from src.models import DeeperGCN
from src.engine import evaluate

hidden_features = 128

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeeperGCN(
    input_features,
    num_classes,
    hidden_features,
    conv_type = "GAT",
    act = "relu",
    norm = "batch",
    num_layers = 4,
    use_cluster_pooling = False,
    readout = "mean",
    dropout = 0.2,
    edge_dim = edge_dim
).to(device)
criterion = torch.nn.CrossEntropyLoss().to(device)
prev_loss = None
if state_dict is not None:
  print("Loading previously saved state dictionary")
  model.load_state_dict(state_dict)
  prev_loss, _ = evaluate(model.to(device), test_loader, criterion, device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
params = sum([p.numel() for p in model.parameters() if p.requires_grad])
print(f"There are {params:,} trainable parameters.")
print()
print(model)
# Out:
# There are 71,434 trainable parameters.
#
# DeeperGCN(
#   (fc_in): Linear(in_features=3, out_features=128, bias=True)
#   (fc_out): Linear(in_features=128, out_features=10, bias=True)
#   (out_act): ReLU(inplace=True)
#   (layers): ModuleList(
#     (0): DeepGCNLayer(block=res+)
#     (1): DeepGCNLayer(block=res+)
#     (2): DeepGCNLayer(block=res+)
#     (3): DeepGCNLayer(block=res+)
#   )
# )

# %% [markdown]
# ```
# There are 71,434 trainable parameters.
#
# DeeperGCN(
#   (fc_in): Linear(in_features=3, out_features=128, bias=True)
#   (fc_out): Linear(in_features=128, out_features=10, bias=True)
#   (out_act): ReLU(inplace=True)
#   (layers): ModuleList(
#     (0): DeepGCNLayer(block=res+)
#     (1): DeepGCNLayer(block=res+)
#     (2): DeepGCNLayer(block=res+)
#     (3): DeepGCNLayer(block=res+)
#   )
# )
# ```

# %% [markdown]
# ## Train

# %%
from src.engine import train, evaluate
from src.utils import calculate_accuracy

EPOCHS = 200
train_loss = []
train_acc = []
valid_loss = []
valid_acc = []
best_loss = float('inf')
best_loss = float('inf')
if prev_loss is not None:
  print(f"Training from previous best loss: {prev_loss}")
  best_loss = prev_loss

for epoch in range(1, EPOCHS + 1):
  print(f"\nEpoch: {epoch}\n")
  loss, acc = train(model, train_loader, criterion, optimizer, device)
  train_loss.append(loss)
  train_acc.append(acc)
  print(f"Train Loss: {train_loss[-1]:.3f}, Train Accuracy: {train_acc[-1]:.2f}")

  loss, acc = evaluate(model, valid_loader, criterion, device)
  valid_loss.append(loss)
  valid_acc.append(acc)
  print(f"Validation Loss: {valid_loss[-1]:.3f}, Validation Accuracy: {valid_acc[-1]:.2f}")

  if loss < best_loss:
    best_loss = loss
    torch.save(model.state_dict(), path)
# Out:
# Epoch: 1
#
# Train Loss: 1.996, Train Accuracy: 0.24
# Validation Loss: 1.918, Validation Accuracy: 0.26
#
# Epoch: 2
#
# Train Loss: 1.873, Train Accuracy: 0.29
# Validation Loss: 1.806, Validation Accuracy: 0.32
#
# Epoch: 3
#
# Train Loss: 1.812, Train Accuracy: 0.32
# Validation Loss: 1.753, Validation Accuracy: 0.35
#
# Epoch: 4
#
# Train Loss: 1.767, Train Accuracy: 0.34
# Validation Loss: 1.695, Validation Accuracy: 0.38
#
# Epoch: 5
#
# Train Loss: 1.744, Train Accuracy: 0.35
# Validation Loss: 1.686, Validation Accuracy: 0.38
#
# Epoch: 6
#
# Train Loss: 1.722, Train Accuracy: 0.36
# Validation Loss: 1.645, Validation Accuracy: 0.40
#
# Epoch: 7
#
# Train Loss: 1.705, Train Accuracy: 0.37
# Validation Loss: 1.702, Validation Accuracy: 0.38
#
# Epoch: 8
#
# Train Loss: 1.698, Train Accuracy: 0.37
# Validation Loss: 1.625, Validation Accuracy: 0.40
#
# Epoch: 9
#
# Train Loss: 1.686, Train Accuracy: 0.38
# Validation Loss: 1.587, Validation Accuracy: 0.42
#
# Epoch: 10
#
# Train Loss: 1.672, Train Accuracy: 0.38
# Validation Loss: 1.580, Validation Accuracy: 0.42
#
# Epoch: 11
#
# Train Loss: 1.657, Train Accuracy: 0.39
# Validation Loss: 1.589, Validation Accuracy: 0.42
#
# Epoch: 12
#
# Train Loss: 1.654, Train Accuracy: 0.39
# Validation Loss: 1.608, Validation Accuracy: 0.41
#
# Epoch: 13
#
# Train Loss: 1.655, Train Accuracy: 0.39
# Validation Loss: 1.622, Validation Accuracy: 0.40
#
# Epoch: 14
#
# Train Loss: 1.641, Train Accuracy: 0.40
# Validation Loss: 1.585, Validation Accuracy: 0.42
#
# Epoch: 15
#
# Train Loss: 1.639, Train Accuracy: 0.40
# Validation Loss: 1.572, Validation Accuracy: 0.43
#
# Epoch: 16
#
# Train Loss: 1.628, Train Accuracy: 0.40
# Validation Loss: 1.545, Validation Accuracy: 0.44
#
# Epoch: 17
#
# Train Loss: 1.629, Train Accuracy: 0.40
# Validation Loss: 1.533, Validation Accuracy: 0.45
#
# Epoch: 18
#
# Train Loss: 1.623, Train Accuracy: 0.40
# Validation Loss: 1.546, Validation Accuracy: 0.44
#
# Epoch: 19
#
# Train Loss: 1.623, Train Accuracy: 0.40
# Validation Loss: 1.545, Validation Accuracy: 0.44
#
# Epoch: 20
#
# Train Loss: 1.616, Train Accuracy: 0.41
# Validation Loss: 1.563, Validation Accuracy: 0.44
#
# Epoch: 21
#
# Train Loss: 1.612, Train Accuracy: 0.41
# Validation Loss: 1.550, Validation Accuracy: 0.44
#
# Epoch: 22
#
# Train Loss: 1.626, Train Accuracy: 0.40
# Validation Loss: 1.541, Validation Accuracy: 0.44
#
# Epoch: 23
#
# Train Loss: 1.620, Train Accuracy: 0.41
# Validation Loss: 1.530, Validation Accuracy: 0.45
#
# Epoch: 24
#
# Train Loss: 1.610, Train Accuracy: 0.41
# Validation Loss: 1.569, Validation Accuracy: 0.43
#
# Epoch: 25
#
# Train Loss: 1.634, Train Accuracy: 0.40
# Validation Loss: 1.602, Validation Accuracy: 0.42
#
# Epoch: 26
#
# Train Loss: 1.648, Train Accuracy: 0.40
# Validation Loss: 1.579, Validation Accuracy: 0.43
#
# Epoch: 27
#
# Train Loss: 1.613, Train Accuracy: 0.41
# Validation Loss: 1.578, Validation Accuracy: 0.42
#
# Epoch: 28
#
# Train Loss: 1.614, Train Accuracy: 0.41
# Validation Loss: 1.525, Validation Accuracy: 0.46
#
# Epoch: 29
#
# Train Loss: 1.606, Train Accuracy: 0.41
# Validation Loss: 1.555, Validation Accuracy: 0.44
#
# Epoch: 30
#
# Train Loss: 1.612, Train Accuracy: 0.41
# Validation Loss: 1.540, Validation Accuracy: 0.44
#
# Epoch: 31
#
# Train Loss: 1.605, Train Accuracy: 0.42
# Validation Loss: 1.541, Validation Accuracy: 0.45
#
# Epoch: 32
#
# Train Loss: 1.603, Train Accuracy: 0.42
# Validation Loss: 1.515, Validation Accuracy: 0.45
#
# Epoch: 33
#
# Train Loss: 1.609, Train Accuracy: 0.41
# Validation Loss: 1.541, Validation Accuracy: 0.44
#
# Epoch: 34
#
# Train Loss: 1.614, Train Accuracy: 0.41
# Validation Loss: 1.560, Validation Accuracy: 0.44
#
# Epoch: 35
#
# Train Loss: 1.599, Train Accuracy: 0.42
# Validation Loss: 1.553, Validation Accuracy: 0.43
#
# Epoch: 36
#
# Train Loss: 1.598, Train Accuracy: 0.41
# Validation Loss: 1.551, Validation Accuracy: 0.44
#
# Epoch: 37
#
# Train Loss: 1.594, Train Accuracy: 0.42
# Validation Loss: 1.559, Validation Accuracy: 0.44
#
# Epoch: 38
#
# Train Loss: 1.607, Train Accuracy: 0.41
# Validation Loss: 1.519, Validation Accuracy: 0.45
#
# Epoch: 39
#
# Train Loss: 1.590, Train Accuracy: 0.42
# Validation Loss: 1.568, Validation Accuracy: 0.44
#
# Epoch: 40
#
# Train Loss: 1.604, Train Accuracy: 0.41
# Validation Loss: 1.572, Validation Accuracy: 0.44
#
# Epoch: 41
#
# Train Loss: 1.618, Train Accuracy: 0.41
# Validation Loss: 1.531, Validation Accuracy: 0.45
#
# Epoch: 42
#
# Train Loss: 1.601, Train Accuracy: 0.41
# Validation Loss: 1.559, Validation Accuracy: 0.45
#
# Epoch: 43
#
# Train Loss: 1.595, Train Accuracy: 0.42
# Validation Loss: 1.550, Validation Accuracy: 0.44
#
# Epoch: 44
#
# Train Loss: 1.620, Train Accuracy: 0.41
# Validation Loss: 1.546, Validation Accuracy: 0.45
#
# Epoch: 45
#
# Train Loss: 1.618, Train Accuracy: 0.41
# Validation Loss: 1.551, Validation Accuracy: 0.44
#
# Epoch: 46
#
# Train Loss: 1.621, Train Accuracy: 0.41
# Validation Loss: 1.567, Validation Accuracy: 0.43
#
# Epoch: 47
#
# Train Loss: 1.609, Train Accuracy: 0.41
# Validation Loss: 1.550, Validation Accuracy: 0.44
#
# Epoch: 48
#
# Train Loss: 1.641, Train Accuracy: 0.40
# Validation Loss: 1.538, Validation Accuracy: 0.45
#
# Epoch: 49
#
# Train Loss: 1.629, Train Accuracy: 0.40
# Validation Loss: 1.626, Validation Accuracy: 0.41
#
# Epoch: 50
#
# Train Loss: 1.619, Train Accuracy: 0.41
# Validation Loss: 1.579, Validation Accuracy: 0.43
#
# Epoch: 51
#
# Train Loss: 1.620, Train Accuracy: 0.41
# Validation Loss: 1.554, Validation Accuracy: 0.44
#
# Epoch: 52
#
# Train Loss: 1.636, Train Accuracy: 0.40
# Validation Loss: 1.579, Validation Accuracy: 0.44
#
# Epoch: 53
#
# Train Loss: 1.632, Train Accuracy: 0.40
# Validation Loss: 1.608, Validation Accuracy: 0.42
#
# Epoch: 54
#
# Train Loss: 1.635, Train Accuracy: 0.40
# Validation Loss: 1.540, Validation Accuracy: 0.44
#
# Epoch: 55
#
# Train Loss: 1.604, Train Accuracy: 0.41
# Validation Loss: 1.528, Validation Accuracy: 0.45
#
# Epoch: 56
#
# Train Loss: 1.629, Train Accuracy: 0.40
# Validation Loss: 1.555, Validation Accuracy: 0.44
#
# Epoch: 57
#
# Train Loss: 1.643, Train Accuracy: 0.40
# Validation Loss: 1.627, Validation Accuracy: 0.41
#
# Epoch: 58
#
# Train Loss: 1.682, Train Accuracy: 0.38
# Validation Loss: 1.598, Validation Accuracy: 0.41
#
# Epoch: 182
#
# Train Loss: 1.786, Train Accuracy: 0.35
# Validation Loss: 1.790, Validation Accuracy: 0.34
#
# Epoch: 183
#
# Train Loss: 1.799, Train Accuracy: 0.34
# Validation Loss: 1.821, Validation Accuracy: 0.33
#
# Epoch: 184
#
# Train Loss: 1.792, Train Accuracy: 0.34
# Validation Loss: 1.761, Validation Accuracy: 0.35
#
# Epoch: 185
#
# Train Loss: 1.774, Train Accuracy: 0.35
# Validation Loss: 1.815, Validation Accuracy: 0.33
#
# Epoch: 186
#
# Train Loss: 1.765, Train Accuracy: 0.35
# Validation Loss: 1.766, Validation Accuracy: 0.35
#
# Epoch: 187
#
# Train Loss: 1.760, Train Accuracy: 0.36
# Validation Loss: 1.760, Validation Accuracy: 0.36
#
# Epoch: 188
#
# Train Loss: 1.792, Train Accuracy: 0.34
# Validation Loss: 1.882, Validation Accuracy: 0.34
#
# Epoch: 189
#
# Train Loss: 1.771, Train Accuracy: 0.35
# Validation Loss: 1.762, Validation Accuracy: 0.38
#
# Epoch: 190
#
# Train Loss: 1.770, Train Accuracy: 0.35
# Validation Loss: 1.744, Validation Accuracy: 0.37
#
# Epoch: 191
#
# Train Loss: 1.766, Train Accuracy: 0.35
# Validation Loss: 1.796, Validation Accuracy: 0.37
#
# Epoch: 192
#
# Train Loss: 1.759, Train Accuracy: 0.35
# Validation Loss: 1.773, Validation Accuracy: 0.35
#
# Epoch: 193
#
# Train Loss: 1.762, Train Accuracy: 0.36
# Validation Loss: 1.771, Validation Accuracy: 0.36
#
# Epoch: 194
#
# Train Loss: 1.775, Train Accuracy: 0.35
# Validation Loss: 1.777, Validation Accuracy: 0.35
#
# Epoch: 195
#
# Train Loss: 1.783, Train Accuracy: 0.34
# Validation Loss: 1.788, Validation Accuracy: 0.35
#
# Epoch: 196
#
# Train Loss: 1.785, Train Accuracy: 0.35
# Validation Loss: 1.788, Validation Accuracy: 0.37
#
# Epoch: 197
#
# Train Loss: 1.776, Train Accuracy: 0.35
# Validation Loss: 1.832, Validation Accuracy: 0.35
#
# Epoch: 198
#
# Train Loss: 1.771, Train Accuracy: 0.35
# Validation Loss: 1.883, Validation Accuracy: 0.37
#
# Epoch: 199
#
# Train Loss: 1.776, Train Accuracy: 0.35
# Validation Loss: 1.821, Validation Accuracy: 0.33
#
# Epoch: 200
#
# Train Loss: 1.802, Train Accuracy: 0.34
# Validation Loss: 1.783, Validation Accuracy: 0.36

# %% [markdown]
# ## Evaluate on the Test set

# %%
# load best model
model.load_state_dict(torch.load(path))
test_loss, test_acc = evaluate(model.to(device), test_loader, criterion, device)
print(f"Test Loss: {test_loss:.3f}")
print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Test Loss: 1.519
# Test Accuracy: 0.44%

# %% [markdown]
# ## Plot Loss and Accuracy Curves

# %%
import matplotlib.pyplot as plt

x = [i for i in range(len(valid_loss))]

plt.plot(x, train_loss, label="Train Loss")
plt.plot(x, valid_loss, label="Validation Loss")
plt.legend()
plt.show()

# %%
plt.plot(x, train_acc, label="Train Accuracy")
plt.plot(x, valid_acc, label="Validation Accuracy")
plt.legend()
plt.show()

# %%
# reaching epoch 193 (out of 1 to 200) after 4h16m
