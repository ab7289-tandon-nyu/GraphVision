# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 1.13.0+cu116
#      |████████████████████████████████| 9.4 MB 41.7 MB/s
#      |████████████████████████████████| 4.6 MB 37.6 MB/s
#      |████████████████████████████████| 3.2 MB 37.8 MB/s
#      |████████████████████████████████| 512 kB 36.1 MB/s
#      |████████████████████████████████| 280 kB 79.2 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
# Install our repo
# !git clone -b models "https://github.com/ab7289-tandon-nyu/GraphVision.git"
# !cp -r /content/GraphVision/src/ .

# !pip install -q git+https://github.com/ab7289-tandon-nyu/GraphVision.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 121 kB 10.6 MB/s
#      |████████████████████████████████| 1.6 MB 44.7 MB/s
#      |████████████████████████████████| 83 kB 2.7 MB/s
#   Building wheel for GraphVision (PEP 517) ... done

# %%
SEED = 1234

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
from src.transforms import get_transforms
from src.datasets import get_datasets, get_dataloaders

transforms = get_transforms("cartesian")
train_dataset, valid_dataset, test_dataset = get_datasets(".data/", 
                        "CIFAR10", pre_transforms = None,
                        transforms = transforms)
BATCH_SIZE = 128

train_loader, valid_loader, test_loader = get_dataloaders(train_dataset,
                                                          valid_dataset,
                                                          test_dataset,
                                                          batch_size=(BATCH_SIZE, 1, 1),
                                                          drop_last = False)
# Out:
# Downloading https://data.pyg.org/datasets/benchmarking-gnns/CIFAR10_v2.zip
# Extracting .data/CIFAR10/raw/CIFAR10_v2.zip
# Processing...
# Done!

# %% [markdown]
# ## Review batch attributes

# %%
sample_batch = next(iter(train_loader))

print()
print(sample_batch)
print("=====================================================================")

# Gather some statistics about the first graph.
print(f"Number of features:  {sample_batch.num_features}")
print(f"Number of node features: {sample_batch.num_node_features}")
print(f'Number of nodes: {sample_batch.num_nodes}')
print(f'Number of edges: {sample_batch.num_edges}')
print(f'Average node degree: {sample_batch.num_edges / sample_batch.num_nodes:.2f}')
print(f'Has isolated nodes: {sample_batch.has_isolated_nodes()}')
print(f'Has self-loops: {sample_batch.has_self_loops()}')
# Out:
# DataBatch(x=[14981, 3], edge_index=[2, 134829], edge_attr=[134829, 2], y=[128], pos=[14981, 2], edge_weight=[134829], batch=[14981], ptr=[129])
# =====================================================================
# Number of features:  3
# Number of node features: 3
# Number of nodes: 14981
# Number of edges: 134829
# Average node degree: 9.00
# Has isolated nodes: False
# Has self-loops: True

# %%
# store edge dimension
edge_dim = sample_batch.edge_attr.size(-1)
edge_dim
# store number of features in graph batch
input_features = test_dataset.num_features
# store number of classes for classification
num_classes = test_dataset.num_classes

print(f"Number of features: {input_features}")
print(f"Number of classes: {num_classes}")
print(f"Edge Attr Dimension: {edge_dim}")
# Out:
# Number of features: 3
# Number of classes: 10
# Edge Attr Dimension: 2

# %%
from pathlib import Path

save_loc = "" # put save location here
model_name = "GeneralConv_clus-false_BN_RELU_h128_layer4.pt"

file_path = save_loc + model_name
path = Path(file_path)
state_dict = None
if path.exists() and path.is_file():
  print("Found Save!")
  state_dict = torch.load(path)
else:
  print("Creating new Model")
# Out:
# Creating new Model

# %% [markdown]
# ## Create our Model

# %%
from src.models import DeeperGCN
from src.engine import evaluate

hidden_features = 128

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeeperGCN(
    input_features,
    num_classes,
    hidden_features,
    conv_type = "General",
    act = "relu",
    norm = "batch",
    num_layers = 4,
    use_cluster_pooling = False,
    readout = "mean",
    dropout = 0.2,
    edge_dim = edge_dim
).to(device)
criterion = torch.nn.CrossEntropyLoss().to(device)
prev_loss = None
if state_dict is not None:
  print("Loading previously saved state dictionary")
  model.load_state_dict(state_dict)
  prev_loss, _ = evaluate(model.to(device), test_loader, criterion, device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
params = sum([p.numel() for p in model.parameters() if p.requires_grad])
print(f"There are {params:,} trainable parameters.")
print()
print(model)
# Out:
# There are 70,410 trainable parameters.
#
# DeeperGCN(
#   (fc_in): Linear(in_features=3, out_features=128, bias=True)
#   (fc_out): Linear(in_features=128, out_features=10, bias=True)
#   (out_act): ReLU(inplace=True)
#   (layers): ModuleList(
#     (0): DeepGCNLayer(block=res+)
#     (1): DeepGCNLayer(block=res+)
#     (2): DeepGCNLayer(block=res+)
#     (3): DeepGCNLayer(block=res+)
#   )
# )

# %% [markdown]
# ```
# There are 70,410 trainable parameters.
#
# DeeperGCN(
#   (fc_in): Linear(in_features=3, out_features=128, bias=True)
#   (fc_out): Linear(in_features=128, out_features=10, bias=True)
#   (out_act): ReLU(inplace=True)
#   (layers): ModuleList(
#     (0): DeepGCNLayer(block=res+)
#     (1): DeepGCNLayer(block=res+)
#     (2): DeepGCNLayer(block=res+)
#     (3): DeepGCNLayer(block=res+)
#   )
# )
# ```

# %% [markdown]
# ## Train

# %%
from src.engine import train, evaluate
from src.utils import calculate_accuracy

EPOCHS = 200
train_loss = []
train_acc = []
valid_loss = []
valid_acc = []
best_loss = float('inf')
best_loss = float('inf')
if prev_loss is not None:
  print(f"Training from previous best loss: {prev_loss}")
  best_loss = prev_loss

for epoch in range(1, EPOCHS + 1):
  print(f"\nEpoch: {epoch}\n")
  loss, acc = train(model, train_loader, criterion, optimizer, device)
  train_loss.append(loss)
  train_acc.append(acc)
  print(f"Train Loss: {train_loss[-1]:.3f}, Train Accuracy: {train_acc[-1]:.2f}")

  loss, acc = evaluate(model, valid_loader, criterion, device)
  valid_loss.append(loss)
  valid_acc.append(acc)
  print(f"Validation Loss: {valid_loss[-1]:.3f}, Validation Accuracy: {valid_acc[-1]:.2f}")

  if loss < best_loss:
    best_loss = loss
    torch.save(model.state_dict(), path)
# Out:
# Epoch: 1
#
# Train Loss: 2.407, Train Accuracy: 0.16
# Validation Loss: 2.175, Validation Accuracy: 0.18
#
# Epoch: 2
#
# Train Loss: 2.179, Train Accuracy: 0.17
# Validation Loss: 2.107, Validation Accuracy: 0.20
#
# Epoch: 3
#
# Train Loss: 2.163, Train Accuracy: 0.18
# Validation Loss: 2.077, Validation Accuracy: 0.21
#
# Epoch: 4
#
# Train Loss: 2.102, Train Accuracy: 0.20
# Validation Loss: 2.008, Validation Accuracy: 0.24
#
# Epoch: 5
#
# Train Loss: 2.061, Train Accuracy: 0.21
# Validation Loss: 1.966, Validation Accuracy: 0.24
#
# Epoch: 6
#
# Train Loss: 2.008, Train Accuracy: 0.23
# Validation Loss: 1.947, Validation Accuracy: 0.24
#
# Epoch: 7
#
# Train Loss: 1.972, Train Accuracy: 0.24
# Validation Loss: 2.470, Validation Accuracy: 0.22
#
# Epoch: 8
#
# Train Loss: 1.949, Train Accuracy: 0.25
# Validation Loss: 1.886, Validation Accuracy: 0.28
#
# Epoch: 9
#
# Train Loss: 1.934, Train Accuracy: 0.25
# Validation Loss: 1.516, Validation Accuracy: 0.46
#
# Epoch: 182
#
# Train Loss: 1.660, Train Accuracy: 0.38
# Validation Loss: 1.516, Validation Accuracy: 0.45
#
# Epoch: 183
#
# Train Loss: 1.662, Train Accuracy: 0.38
# Validation Loss: 1.523, Validation Accuracy: 0.44
#
# Epoch: 184
#
# Train Loss: 1.652, Train Accuracy: 0.38
# Validation Loss: 1.520, Validation Accuracy: 0.45
#
# Epoch: 185
#
# Train Loss: 1.652, Train Accuracy: 0.38
# Validation Loss: 1.494, Validation Accuracy: 0.46
#
# Epoch: 186
#
# Train Loss: 1.664, Train Accuracy: 0.38
# Validation Loss: 1.535, Validation Accuracy: 0.44
#
# Epoch: 187
#
# Train Loss: 1.660, Train Accuracy: 0.38
# Validation Loss: 1.486, Validation Accuracy: 0.46
#
# Epoch: 188
#
# Train Loss: 1.656, Train Accuracy: 0.38
# Validation Loss: 1.540, Validation Accuracy: 0.45
#
# Epoch: 189
#
# Train Loss: 1.655, Train Accuracy: 0.38
# Validation Loss: 1.492, Validation Accuracy: 0.46
#
# Epoch: 190
#
# Train Loss: 1.668, Train Accuracy: 0.38
# Validation Loss: 1.549, Validation Accuracy: 0.45
#
# Epoch: 191
#
# Train Loss: 1.662, Train Accuracy: 0.38
# Validation Loss: 1.560, Validation Accuracy: 0.43
#
# Epoch: 192
#
# Train Loss: 1.663, Train Accuracy: 0.38
# Validation Loss: 1.545, Validation Accuracy: 0.43
#
# Epoch: 193
#
# Train Loss: 1.663, Train Accuracy: 0.38
# Validation Loss: 1.504, Validation Accuracy: 0.46
#
# Epoch: 194
#
# Train Loss: 1.661, Train Accuracy: 0.38
# Validation Loss: 1.525, Validation Accuracy: 0.44
#
# Epoch: 195
#
# Train Loss: 1.654, Train Accuracy: 0.38
# Validation Loss: 1.516, Validation Accuracy: 0.44
#
# Epoch: 196
#
# Train Loss: 1.670, Train Accuracy: 0.38
# Validation Loss: 1.522, Validation Accuracy: 0.44
#
# Epoch: 197
#
# Train Loss: 1.654, Train Accuracy: 0.38
# Validation Loss: 1.487, Validation Accuracy: 0.46
#
# Epoch: 198
#
# Train Loss: 1.658, Train Accuracy: 0.38
# Validation Loss: 1.490, Validation Accuracy: 0.46
#
# Epoch: 199
#
# Train Loss: 1.655, Train Accuracy: 0.38
# Validation Loss: 1.586, Validation Accuracy: 0.40
#
# Epoch: 200
#
# Train Loss: 1.655, Train Accuracy: 0.38
# Validation Loss: 1.494, Validation Accuracy: 0.45

# %% [markdown]
# ## Evaluate on the Test set

# %%
# load best model
model.load_state_dict(torch.load(path))
test_loss, test_acc = evaluate(model.to(device), test_loader, criterion, device)
print(f"Test Loss: {test_loss:.3f}")
print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Test Loss: 1.492
# Test Accuracy: 0.46%

# %% [markdown]
# ## Plot Loss and Accuracy Curves

# %%
import matplotlib.pyplot as plt

x = [i for i in range(len(valid_loss))]

plt.plot(x, train_loss, label="Train Loss")
plt.plot(x, valid_loss, label="Validation Loss")
plt.legend()
plt.show()

# %%
plt.plot(x, train_acc, label="Train Accuracy")
plt.plot(x, valid_acc, label="Validation Accuracy")
plt.legend()
plt.show()
